# %%
# !pip install spacy nltk
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 42.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !ls
# Out:
# Code	 mbl_number.py	qualification.py  skills.py
# mail.py  name.py	README.md	  text.py

# %%
# !pip install PyPDF2 docx2txt

# %%
# !sed -i '/pip install/d' text.py

# %%
import text

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b779010-99d3-4de6-a11a-a14b80e6384f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b779010-99d3-4de6-a11a-a14b80e6384f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import docx2txt
from PyPDF2 import PdfReader, PdfFileWriter, PdfFileMerger

#Extracting text from DOCX
def doctotext(m):
    temp = docx2txt.process(m)
    resume_text = [line.replace('\t', ' ') for line in temp.split('\n') if line]
    text = ' '.join(resume_text)
    return (text)

#Extracting text from PDF
def pdftotext(m):
    # pdf file object
    # you can find find the pdf file with complete code in below
    pdfFileObj = open(m, 'rb')

    # pdf reader object
    pdfFileReader = PdfReader(pdfFileObj)

    # number of pages in pdf
    num_pages = pdfFileReader.num_pages

    currentPageNumber = 0
    text = ''

    # Loop in all the pdf pages.
    while(currentPageNumber < num_pages ):

        # Get the specified pdf page object.
        pdfPage = pdfFileReader.pages[currentPageNumber]
        text += pdfPage.extract_text()

        # Increment the page number.
        currentPageNumber += 1
    return (text)

# %%
from PyPDF2 import PdfReader

def pdftotext(file_path):
    pdf_reader = PdfReader(file_path)
    text = ""

    for page in pdf_reader.pages:
        text += page.extract_text() or ""

    return text

# %%
import docx2txt
from PyPDF2 import PdfReader

# DOCX
def doctotext(file_path):
    temp = docx2txt.process(file_path)
    lines = [line.replace('\t',' ') for line in temp.split('\n') if line]
    return ' '.join(lines)

# PDF
def pdftotext(file_path):
    pdf_reader = PdfReader(file_path)
    text = ""
    for page in pdf_reader.pages:
        text += page.extract_text() or ""
    return text

# Unified function
def extract_resume(file_path):
    if file_path.endswith(".pdf"):
        return pdftotext(file_path)
    elif file_path.endswith(".docx"):
        return doctotext(file_path)
    else:
        raise ValueError("Only .pdf and .docx supported")

# %%
resume_text = extract_resume("Maheshree Katla.pdf")
print(resume_text[:900])
# Out:
# Maheshree Katla
# Contact:  78882573637
# Email:  maheshree15@gmail.com
# LinkedIn:  Maheshree Katla | LinkedIn
# About Me
# Innovative and detail-oriented Computer Engineering student pursuing a Bachelor's degree at New
# Horizon Institute of Technology and Management. Strong foundational knowledge in software
# development, data structures, and computer systems. Passionate about emerging technologies like
# AI, with experience in building academic projects using Python and web technologies. Collaborative
# team player with a strong commitment to continuous learning and professional growth.
# Education
# Bachelor of Engineering (Computer Engineering)
# New Horizon Institute of Technology and Management, Mumbai University
# Pursuing (Expected Graduation: 2026)
# HSC
# Fatima High School and Junior College
# Higher Secondary Education (2020–2022)
# 66.17%
# SSC
# T.M.S. High School and Junior College
# Secondary Educati
